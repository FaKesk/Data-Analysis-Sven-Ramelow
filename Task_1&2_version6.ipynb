# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import interpolate
from sklearn.preprocessing import LabelEncoder
from collections import Counter
import imblearn
from imblearn.over_sampling import SMOTE
from imblearn.over_sampling import RandomOverSampler
from sklearn.model_selection import ShuffleSplit
df=pd.read_csv("Clear_Path_300ms_delay01_subt2.csv",sep="	")
c = 3e+8;
#computing the frequencies
freq_array = np.array((c*1e+9)/df["Wavelength(nm)"])
df["Frequency (s^(-1))"] = freq_array
#labelling the frequency values by creating classes
X = np.reshape(freq_array, (2068, 1))
data = df.values
data[:,:517] = 0
#creating a dictionary for sampling_strategy
counter = Counter(y)
for k,v in counter.items():
 per = v / len(y) * 100
 print('Class=%d, n=%d (%.3f%%)' % (k, v, per))
# Out:
# Class=0, n=1 (20.000%)
# Class=1, n=1 (20.000%)
# Class=2, n=1 (20.000%)
# Class=3, n=1 (20.000%)
# Class=4, n=1 (20.000%)

# %%
values=np.empty(2068); values.fill(3)
strategy = dict(list(enumerate(values)))
oversample = SMOTE(sampling_strategy = strategy)
# fit and apply the transform
X_over, y_over = oversample.fit_resample(X, y)
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 0 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 1 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 2 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 3 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 4 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 5 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 6 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 7 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 8 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 9 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 10 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 11 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 12 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 13 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 14 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 15 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 16 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 17 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 18 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 19 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 20 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 21 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 22 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 23 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 24 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 25 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 26 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 27 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 28 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 29 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 30 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 31 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 32 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 33 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 34 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 35 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 36 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 37 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 38 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 39 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 40 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 41 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 42 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 43 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 44 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 45 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 46 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 47 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 48 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 49 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 50 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 51 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 52 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 53 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 54 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 55 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 56 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 57 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 58 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 59 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 60 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 61 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 62 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 63 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 64 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 65 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 66 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 67 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 68 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 69 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 70 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 71 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 72 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 73 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 74 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 75 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 76 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 77 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 78 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 79 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 80 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 81 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 82 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 83 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 84 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 85 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 86 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 87 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 88 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 89 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 90 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 91 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 92 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 93 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 94 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 95 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 96 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 97 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 98 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 99 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 100 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 101 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 102 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 103 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 104 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 105 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 106 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 107 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 108 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 109 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 110 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 111 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 112 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 113 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 114 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 115 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 116 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 117 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 118 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 119 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 120 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 121 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 122 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 123 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 124 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 125 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 126 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 127 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 128 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 129 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 130 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 131 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 132 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 133 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 134 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 135 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 136 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 137 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 138 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 139 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 140 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 141 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 142 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 143 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 144 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 145 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 146 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 147 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 148 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 149 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 150 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 151 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 152 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 153 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 154 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 155 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 156 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 157 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 158 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 159 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 160 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 161 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 162 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 163 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 164 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 165 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 166 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 167 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 168 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 169 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 170 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 171 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 172 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 173 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 174 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 175 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 176 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 177 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 178 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 179 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 180 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 181 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 182 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 183 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 184 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 185 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 186 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 187 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 188 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 189 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 190 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 191 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 192 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# ...
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 2010 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 2011 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 2012 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 2013 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 2014 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 2015 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 2016 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 2017 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 2018 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 2019 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 2020 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 2021 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 2022 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 2023 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 2024 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 2025 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 2026 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 2027 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 2028 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 2029 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 2030 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 2031 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 2032 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 2033 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 2034 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 2035 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 2036 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 2037 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 2038 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 2039 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 2040 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 2041 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 2042 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 2043 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 2044 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 2045 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 2046 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 2047 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 2048 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 2049 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 2050 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 2051 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 2052 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 2053 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 2054 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 2055 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 2056 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 2057 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 2058 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 2059 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 2060 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 2061 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 2062 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 2063 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 2064 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 2065 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 2066 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\imblearn\utils\_validation.py:318: UserWarning: After over-sampling, the number of samples (3.0) in class 2067 will be larger than the number of samples in the majority class (class #0 -> 1)
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-03f2875ce082> in <module>
#       3 oversample = SMOTE(sampling_strategy = strategy)
#       4 # fit and apply the transform
# ----> 5 X_over, y_over = oversample.fit_resample(X, y)
#
# ~\anaconda3\lib\site-packages\imblearn\base.py in fit_resample(self, X, y)
#      81         )
#      82
# ---> 83         output = self._fit_resample(X, y)
#      84
#      85         y_ = (label_binarize(output[1], np.unique(y))
#
# ~\anaconda3\lib\site-packages\imblearn\over_sampling\_smote.py in _fit_resample(self, X, y)
#     730
#     731             self.nn_k_.fit(X_class)
# --> 732             nns = self.nn_k_.kneighbors(X_class, return_distance=False)[:, 1:]
#     733             X_new, y_new = self._make_samples(
#     734                 X_class, y.dtype, class_sample, X_class, nns, n_samples, 1.0
#
# ~\anaconda3\lib\site-packages\sklearn\neighbors\_base.py in kneighbors(self, X, n_neighbors, return_distance)
#     678         n_samples_fit = self.n_samples_fit_
#     679         if n_neighbors > n_samples_fit:
# --> 680             raise ValueError(
#     681                 "Expected n_neighbors <= n_samples, "
#     682                 " but n_samples = %d, n_neighbors = %d" %
#
# ValueError: Expected n_neighbors <= n_samples,  but n_samples = 1, n_neighbors = 6

# %%
# Out:
# 5
